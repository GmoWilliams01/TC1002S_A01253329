# %%
# Importar las librerías a utilizar
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})

import matplotlib.pylab as plt
import numpy as np

# %%
# Leer los datos a analizar
cars = pd.read_csv("American New Cars of 1993.csv", na_values = ' ')
print('shape: ', cars.shape)
cars.head() 
cars.tail()
# Out:
# shape:  (93, 25)
#               Car Name     Type  Min Price ($US1,000)  Med Price ($US1,000)  \
# 88  Volkswagen Eurovan      Van                  16.6                  19.7
# 89   Volkswagen Passat  Compact                  17.6                  20.0
# 90  Volkswagen Corrado   Sporty                  22.9                  23.3
# 91           Volvo 240  Compact                  21.8                  22.7
# 92           Volvo 850  Midsize                  24.8                  26.7
#
#     Max Price ($US1,000)  City (MPG)  Open Road (MPG)           Airbag  \
# 88                  22.7          17               21             None
# 89                  22.4          21               30             None
# 90                  23.7          18               25             None
# 91                  23.5          21               28           Driver
# 92                  28.5          20               28  DriverPassenger
#
#      Drive train  Cylinders  ...  Fuel tank (Gallons)  \
# ...

# %%
cars.columns
# Out:
# Index(['Car Name', 'Type', 'Min Price ($US1,000)', 'Med Price ($US1,000)',
#        'Max Price ($US1,000)', 'City (MPG)', 'Open Road (MPG)', 'Airbag',
#        'Drive train', 'Cylinders', 'Engine Size (Litres)', 'Horsepower (HP)',
#        'Revs at max power (RPM)', 'Revs at cruising speed (RPM)',
#        'Manual transmission avaiable', 'Fuel tank (Gallons)',
#        'Passenger Capacity (persons)', 'Length (cm)', 'Wheelbase (cm)',
#        'Width (cm)', 'u-turn space (m)', 'rear seat room (cm)',
#        'luggage capacity (m3)', 'Weight (kg)', 'USA or Foreign car'],
#       dtype='object')

# %%
cars.dtypes
# Out:
# Car Name                         object
# Type                             object
# Min Price ($US1,000)            float64
# Med Price ($US1,000)            float64
# Max Price ($US1,000)            float64
# City (MPG)                        int64
# Open Road (MPG)                   int64
# Airbag                           object
# Drive train                      object
# Cylinders                       float64
# Engine Size (Litres)            float64
# Horsepower (HP)                   int64
# Revs at max power (RPM)          object
# Revs at cruising speed (RPM)     object
# Manual transmission avaiable     object
# Fuel tank (Gallons)             float64
# Passenger Capacity (persons)      int64
# Length (cm)                       int64
# Wheelbase (cm)                    int64
# Width (cm)                        int64
# u-turn space (m)                  int64
# rear seat room (cm)             float64
# luggage capacity (m3)           float64
# ...

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=93, step=1)

# %%
#Convertimos las filas vacia a tipo NaN
popNaN = cars.dropna()

popNaN
# Out:
#               Car Name     Type  Min Price ($US1,000)  Med Price ($US1,000)  \
# 0        Acura Integra    Small                  12.9                  15.9
# 1         Acura Legend  Midsize                  29.2                  33.9
# 2              Audi 90  Compact                  25.9                  29.1
# 3             Audi 100  Midsize                  30.8                  37.7
# 4             BMW 535i  Midsize                  23.7                  30.0
# ..                 ...      ...                   ...                   ...
# 87      Volkswagen Fox    Small                   8.7                   9.1
# 89   Volkswagen Passat  Compact                  17.6                  20.0
# 90  Volkswagen Corrado   Sporty                  22.9                  23.3
# 91           Volvo 240  Compact                  21.8                  22.7
# 92           Volvo 850  Midsize                  24.8                  26.7
#
# ...

# %%
print ("Min en Min Price:", cars['Min Price ($US1,000)'].min())
print ("Min en Med Price:", cars['Med Price ($US1,000)'].min())
print ("Min en Max Price:", cars['Max Price ($US1,000)'].min())
print ("MIN en Cylinders:", cars['Cylinders'].min())
print ("Min en Fuel tank (Gallons):", cars['Fuel tank (Gallons)'].min())
print ("Min en Passenger Capacity (persons):", cars['Passenger Capacity (persons)'].min())
print ("Min en Length (cm):", cars['Length (cm)'].min())
print ("Min en Wheelbase (cm):", cars['Wheelbase (cm)'].min())
print ("Min en Width (cm):", cars['Width (cm)'].min())
print ("Min en u-turn space (m):", cars['u-turn space (m)'].min())
print ("MIN en rear seat room (cm):", cars['rear seat room (cm)'].min())
print ("MIN en luggage capacity (m3):", cars['luggage capacity (m3)'].min())
print ("Min en Weight (kg):", cars['Weight (kg)'].min())
# Out:
# Min en Min Price: 6.7
# Min en Med Price: 7.4
# Min en Max Price: 7.9
# MIN en Cylinders: 3.0
# Min en Fuel tank (Gallons): 9.2
# Min en Passenger Capacity (persons): 2
# Min en Length (cm): 358
# Min en Wheelbase (cm): 229
# Min en Width (cm): 152
# Min en u-turn space (m): 10
# MIN en rear seat room (cm): 48.0
# MIN en luggage capacity (m3): 0.17
# Min en Weight (kg): 769

# %%
print ("Max en Min Price:", cars['Min Price ($US1,000)'].max())
print ("Max en Med Price:", cars['Med Price ($US1,000)'].max())
print ("Max en Max Price:", cars['Max Price ($US1,000)'].max())
print ("Max en Cylinders:", cars['Cylinders'].max())
print ("Max en Fuel tank (Gallons):", cars['Fuel tank (Gallons)'].max())
print ("Max en Passenger Capacity (persons):", cars['Passenger Capacity (persons)'].max())
print ("Max en Length (cm):", cars['Length (cm)'].max())
print ("Max en Wheelbase (cm):", cars['Wheelbase (cm)'].max())
print ("Max en Width (cm):", cars['Width (cm)'].max())
print ("Max en u-turn space (m):", cars['u-turn space (m)'].max())
print ("Max en rear seat room (cm):", cars['rear seat room (cm)'].max())
print ("Max en luggage capacity (m3):", cars['luggage capacity (m3)'].max())
print ("Max en Weight (kg):", cars['Weight (kg)'].max())
# Out:
# Max en Min Price: 45.4
# Max en Med Price: 61.9
# Max en Max Price: 80.0
# Max en Cylinders: 8.0
# Max en Fuel tank (Gallons): 27.0
# Max en Passenger Capacity (persons): 8
# Max en Length (cm): 556
# Max en Wheelbase (cm): 302
# Max en Width (cm): 198
# Max en u-turn space (m): 14
# Max en rear seat room (cm): 91.0
# Max en luggage capacity (m3): 0.62
# Max en Weight (kg): 1862

# %%
print ("Media en Min Price:", cars['Min Price ($US1,000)'].mean())
print ("Media en Med Price:", cars['Med Price ($US1,000)'].mean())
print ("Media en Max Price:", cars['Max Price ($US1,000)'].mean())
print ("Media en Cylinders:", cars['Cylinders'].mean())
print ("Media en Fuel tank (Gallons):", cars['Fuel tank (Gallons)'].mean())
print ("Media en Passenger Capacity (persons):", cars['Passenger Capacity (persons)'].mean())
print ("Media en Length (cm):", cars['Length (cm)'].mean())
print ("Media en Wheelbase (cm):", cars['Wheelbase (cm)'].mean())
print ("Media en Width (cm):", cars['Width (cm)'].mean())
print ("Media en u-turn space (m):", cars['u-turn space (m)'].mean())
print ("Media en rear seat room (cm):", cars['rear seat room (cm)'].mean())
print ("Media en luggage capacity (m3):", cars['luggage capacity (m3)'].mean())
print ("Media en Weight (kg):", cars['Weight (kg)'].mean())
# Out:
# Media en Min Price: 17.125806451612902
# Media en Med Price: 19.509677419354837
# Media en Max Price: 21.898924731182806
# Media en Cylinders: 4.967391304347826
# Media en Fuel tank (Gallons): 16.664516129032265
# Media en Passenger Capacity (persons): 5.086021505376344
# Media en Length (cm): 465.4301075268817
# Media en Wheelbase (cm): 264.03225806451616
# Media en Width (cm): 176.21505376344086
# Media en u-turn space (m): 11.827956989247312
# Media en rear seat room (cm): 70.63736263736264
# Media en luggage capacity (m3): 0.39304878048780495
# Media en Weight (kg): 1393.8064516129032

# %%
print ("Mediana en Min Price:", cars['Min Price ($US1,000)'].median())
print ("Mediana en Med Price:", cars['Med Price ($US1,000)'].median())
print ("Mediana en Max Price:", cars['Max Price ($US1,000)'].median())
print ("Mediana en Cylinders:", cars['Cylinders'].median())
print ("Mediana en Fuel tank (Gallons):", cars['Fuel tank (Gallons)'].median())
print ("Mediana en Passenger Capacity (persons):", cars['Passenger Capacity (persons)'].median())
print ("Mediana en Length (cm):", cars['Length (cm)'].median())
print ("Mediana en Wheelbase (cm):", cars['Wheelbase (cm)'].median())
print ("Mediana en Width (cm):", cars['Width (cm)'].median())
print ("Mediana en u-turn space (m):", cars['u-turn space (m)'].median())
print ("Mediana en rear seat room (cm):", cars['rear seat room (cm)'].median())
print ("Mediana en luggage capacity (m3):", cars['luggage capacity (m3)'].median())
print ("Mediana en Weight (kg):", cars['Weight (kg)'].median())
# Out:
# Mediana en Min Price: 14.7
# Mediana en Med Price: 17.7
# Mediana en Max Price: 19.6
# Mediana en Cylinders: 4.0
# Mediana en Fuel tank (Gallons): 16.4
# Mediana en Passenger Capacity (persons): 5.0
# Mediana en Length (cm): 465.0
# Mediana en Wheelbase (cm): 262.0
# Mediana en Width (cm): 175.0
# Mediana en u-turn space (m): 12.0
# Mediana en rear seat room (cm): 70.0
# Mediana en luggage capacity (m3): 0.4
# Mediana en Weight (kg): 1379.0

# %%
print ("Desviación Std en Weight (kg):", cars['Weight (kg)'].std() )

print ("Desviación Std en Min Price:", cars['Min Price ($US1,000)'].std())
print ("Desviación Std en Med Price:", cars['Med Price ($US1,000)'].std())
print ("Desviación Std en Max Price:", cars['Max Price ($US1,000)'].std())
print ("Desviación Std en Cylinders:", cars['Cylinders'].std())
print ("Desviación Std en Fuel tank (Gallons):", cars['Fuel tank (Gallons)'].std())
print ("Desviación Std en Passenger Capacity (persons):", cars['Passenger Capacity (persons)'].std())
print ("Desviación Std en Length (cm):", cars['Length (cm)'].std())
print ("Desviación Std en Wheelbase (cm):", cars['Wheelbase (cm)'].std())
print ("Desviación Std en Width (cm):", cars['Width (cm)'].std())
print ("Desviación Std en u-turn space (m):", cars['u-turn space (m)'].std())
print ("Desviación Std en rear seat room (cm):", cars['rear seat room (cm)'].std())
print ("Desviación Std en luggage capacity (m3):", cars['luggage capacity (m3)'].std())
print ("Desviación Std en Weight (kg):", cars['Weight (kg)'].std())
# Out:
# Desviación Std en Weight (kg): 267.5599184443071
# Desviación Std en Min Price: 8.746028952638603
# Desviación Std en Med Price: 9.659429550580962
# Desviación Std en Max Price: 11.030456794353492
# Desviación Std en Cylinders: 1.304692182605586
# Desviación Std en Fuel tank (Gallons): 3.279370471178428
# Desviación Std en Passenger Capacity (persons): 1.0389785324234753
# Desviación Std en Length (cm): 37.07143452305303
# Desviación Std en Wheelbase (cm): 17.308864035330235
# Desviación Std en Width (cm): 9.597157031897737
# Desviación Std en u-turn space (m): 0.9959009021110572
# Desviación Std en rear seat room (cm): 7.528488830976911
# Desviación Std en luggage capacity (m3): 0.08458597823838064
# Desviación Std en Weight (kg): 267.5599184443071

# %%
fig = plt.figure(figsize=(10, 7))
plt.boxplot(cars['Min Price ($US1,000)'])
plt.title('Min Price ($US1,000)')
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.boxplot(cars['Med Price ($US1,000)'])
plt.title('Med Price ($US1,000)')
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.boxplot(cars['Max Price ($US1,000)'])
plt.title('Max Price ($US1,000)')
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.boxplot(cars['Fuel tank (Gallons)'])
plt.title('Fuel tank (Gallons)')
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.boxplot(cars['Passenger Capacity (persons)'])
plt.title('Passenger Capacity (persons)')
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.boxplot(cars['Horsepower (HP)'])
plt.title('Horsepower (HP)')
plt.show()

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(cars['Min Price ($US1,000)'], bins=30)
plt.show()
# Out:
# /home/guillermo/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(cars['Med Price ($US1,000)'], bins=30)
plt.show()
# Out:
# /home/guillermo/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(cars['Max Price ($US1,000)'], bins=30)
plt.show()
# Out:
# /home/guillermo/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(cars['Fuel tank (Gallons)'], bins=30)
plt.show()
# Out:
# /home/guillermo/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(cars['Passenger Capacity (persons)'], bins=30)
plt.show()
# Out:
# /home/guillermo/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(cars['Horsepower (HP)'], bins=30)
plt.show()
# Out:
# /home/guillermo/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Matriz de correlación reducida en características
#indices = [0,2,4,5,6,12]
#cars2 = pd.DataFrame(cars.data[:, indices], columns = cars.feature_names[indices])
#cars2['PRICE'] = boston.target
corrmat = cars.corr().round(1)
# Se usa la matriz de correlación para dibujar un mapa de calor
sns.heatmap(data=corrmat, annot=True)
# Out:
# <AxesSubplot:>
